# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkarale06/Stock-Prediction/blob/main/Stock_Market_Perfromance_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance #using yfinace API to get real time stock market data

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
start_date = datetime.now() - pd.DateOffset(months=3)
end_date = datetime.now()

# %%
tickers = ['AAPL', 'MSFT', 'NFLX', 'GOOG']

# %%
df_list = []
for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    df_list.append(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-22  123.510002  127.050003  123.449997  125.870003  125.870003
# 2023-05-23  124.930000  125.419998  123.050003  123.290001  123.290001
# 2023-05-24  121.879997  122.750000  120.750000  121.639999  121.639999
# 2023-05-25  125.209999  125.980003  122.900002  124.349998  124.349998
# 2023-05-26  124.065002  126.000000  123.290001  125.430000  125.430000
#
#               Volume
# Date
# 2023-05-22  29760200
# 2023-05-23  24477900
# 2023-05-24  23087900
# 2023-05-25  33812700
# 2023-05-26  25154700

# %%
df = pd.concat(df_list, keys=tickers, names=['Ticker', 'Date'])
print(df.head())
# Out:
#                          Open        High         Low       Close   Adj Close  \
# Ticker Date
# AAPL   2023-05-22  173.979996  174.710007  173.449997  174.199997  173.965073
#        2023-05-23  173.130005  173.380005  171.279999  171.559998  171.328644
#        2023-05-24  171.089996  172.419998  170.520004  171.839996  171.608261
#        2023-05-25  172.410004  173.899994  171.690002  172.990005  172.756714
#        2023-05-26  173.320007  175.770004  173.110001  175.429993  175.193420
#
#                      Volume
# Ticker Date
# AAPL   2023-05-22  43570900
#        2023-05-23  50747300
#        2023-05-24  45143500
#        2023-05-25  56058300
#        2023-05-26  54835000

# %%
df.tail()
# Out:
#                          Open        High         Low       Close   Adj Close  \
# Ticker Date
# GOOG   2023-08-15  131.589996  131.990005  129.819000  130.270004  130.270004
#        2023-08-16  129.279999  130.897995  128.460007  129.110001  129.110001
#        2023-08-17  130.449997  132.490997  129.850006  130.460007  130.460007
#        2023-08-18  129.059998  129.830002  127.000000  128.110001  128.110001
#        2023-08-21  127.849998  129.259598  127.169998  128.510101  128.510101
#
#                      Volume
# Ticker Date
# GOOG   2023-08-15  14769200
#        2023-08-16  17548400
#        2023-08-17  23665600
#        2023-08-18  23619400
#        2023-08-21  11136262

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 63 entries, 2023-05-22 to 2023-08-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       63 non-null     float64
#  1   High       63 non-null     float64
#  2   Low        63 non-null     float64
#  3   Close      63 non-null     float64
#  4   Adj Close  63 non-null     float64
#  5   Volume     63 non-null     int64
# dtypes: float64(5), int64(1)
# memory usage: 3.4 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 252 entries, ('AAPL', Timestamp('2023-05-22 00:00:00')) to ('GOOG', Timestamp('2023-08-21 00:00:00'))
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Adj Close  252 non-null    float64
#  5   Volume     252 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 15.2+ KB

# %%
df = df.reset_index()
print(df.head())
# Out:
#   Ticker       Date        Open        High         Low       Close  \
# 0   AAPL 2023-05-22  173.979996  174.710007  173.449997  174.199997
# 1   AAPL 2023-05-23  173.130005  173.380005  171.279999  171.559998
# 2   AAPL 2023-05-24  171.089996  172.419998  170.520004  171.839996
# 3   AAPL 2023-05-25  172.410004  173.899994  171.690002  172.990005
# 4   AAPL 2023-05-26  173.320007  175.770004  173.110001  175.429993
#
#     Adj Close    Volume
# 0  173.965073  43570900
# 1  171.328644  50747300
# 2  171.608261  45143500
# 3  172.756714  56058300
# 4  175.193420  54835000

# %%
import plotly.express as px
fig  = px.line(df,x = 'Date',y = 'Close',color = 'Ticker', title = 'Market Analysis for last 3 months ')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_1 = px.area(df,x='Date',y = 'Close',facet_col='Ticker',color = "Ticker",
                labels={'Date':'Date', 'Close':'Closing Price', 'Ticker':'Company'},
                title='Stock Prices for Apple, Microsoft, Netflix, and Google')
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-22  123.510002  127.050003  123.449997  125.870003  125.870003
# 2023-05-23  124.930000  125.419998  123.050003  123.290001  123.290001
# 2023-05-24  121.879997  122.750000  120.750000  121.639999  121.639999
# 2023-05-25  125.209999  125.980003  122.900002  124.349998  124.349998
# 2023-05-26  124.065002  126.000000  123.290001  125.430000  125.430000
#
#               Volume
# Date
# 2023-05-22  29760200
# 2023-05-23  24477900
# 2023-05-24  23087900
# 2023-05-25  33812700
# 2023-05-26  25154700

# %%
df['MA10'] = df.groupby('Ticker')['Close'].rolling(window=10).mean().reset_index(0, drop=True)
df['MA20'] = df.groupby('Ticker')['Close'].rolling(window = 20).mean().reset_index(0,drop=True)


for ticker, group in df.groupby('Ticker'):
    print(f'Moving Averages for {ticker}')
    print(group[['MA10', 'MA20']])
# Out:
# Moving Averages for AAPL
#           MA10        MA20
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ..         ...         ...
# 58  181.525002  187.870001
# 59  179.924002  186.943501
# 60  178.207002  185.987001
# 61  177.457002  185.114501
# 62  177.101001  184.241501
#
# [63 rows x 2 columns]
# Moving Averages for GOOG
#            MA10        MA20
# 189         NaN         NaN
# 190         NaN         NaN
# 191         NaN         NaN
# 192         NaN         NaN
# 193         NaN         NaN
# ..          ...         ...
# 247  130.236000  128.359499
# 248  130.283000  128.675999
# 249  130.452000  129.222500
# 250  130.409001  129.612500
# 251  130.066011  129.944005
#
# [63 rows x 2 columns]
# Moving Averages for MSFT
#            MA10        MA20
# 63          NaN         NaN
# 64          NaN         NaN
# 65          NaN         NaN
# 66          NaN         NaN
# ...

# %%
for ticker, group in df.groupby('Ticker'):
    fig = px.line(group, x='Date', y=['Close', 'MA10', 'MA20'],
                  title=f"{ticker} Moving Averages")
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Volatility'] = df.groupby('Ticker')['Close'].pct_change().rolling(window=10).std().reset_index(0, drop=True)
fig = px.line(df, x='Date', y='Volatility',
              color='Ticker',
              title='Volatility of All Companies')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create a DataFrame with the stock prices of Apple and Microsoft
apple = df.loc[df['Ticker'] == 'AAPL', ['Date', 'Close']].rename(columns={'Close': 'AAPL'})
microsoft = df.loc[df['Ticker'] == 'MSFT', ['Date', 'Close']].rename(columns={'Close': 'MSFT'})
df_corr = pd.merge(apple, microsoft, on='Date')



fig = px.scatter(df_corr, x='AAPL', y='MSFT',
                 trendline='ols',
                 title='Correlation between Apple and Microsoft')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-22  123.510002  127.050003  123.449997  125.870003  125.870003
# 2023-05-23  124.930000  125.419998  123.050003  123.290001  123.290001
# 2023-05-24  121.879997  122.750000  120.750000  121.639999  121.639999
# 2023-05-25  125.209999  125.980003  122.900002  124.349998  124.349998
# 2023-05-26  124.065002  126.000000  123.290001  125.430000  125.430000
#
#               Volume
# Date
# 2023-05-22  29760200
# 2023-05-23  24477900
# 2023-05-24  23087900
# 2023-05-25  33812700
# 2023-05-26  25154700

# %%
Google = df.loc[df['Ticker'] == 'GOOG', ['Date', 'Close']].rename(columns={'Close': 'GOOG'})
microsoft = df.loc[df['Ticker'] == 'MSFT', ['Date', 'Close']].rename(columns={'Close': 'MSFT'})
df_corr_0 = pd.merge(Google, microsoft, on='Date')

# %%
fig = px.scatter(df_corr, x='GOOG', y='MSFT',
                 trendline='ols',
                 title='Correlation between Gooogle and Microsoft')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#   Ticker       Date        Open        High         Low       Close  \
# 0   AAPL 2023-05-22  173.979996  174.710007  173.449997  174.199997
# 1   AAPL 2023-05-23  173.130005  173.380005  171.279999  171.559998
# 2   AAPL 2023-05-24  171.089996  172.419998  170.520004  171.839996
# 3   AAPL 2023-05-25  172.410004  173.899994  171.690002  172.990005
# 4   AAPL 2023-05-26  173.320007  175.770004  173.110001  175.429993
#
#     Adj Close    Volume  MA10  MA20  Volatility
# 0  173.965073  43570900   NaN   NaN         NaN
# 1  171.328644  50747300   NaN   NaN         NaN
# 2  171.608261  45143500   NaN   NaN         NaN
# 3  172.756714  56058300   NaN   NaN         NaN
# 4  175.193420  54835000   NaN   NaN         NaN

# %%
unique_values = df['Ticker'].unique()


for value in unique_values:
    print(value)
# Out:
# AAPL
# MSFT
# NFLX
# GOOG

# %%
Netflix = df.loc[df['Ticker'] == 'NFLX', ['Date', 'Close']].rename(columns={'Close': 'NFLX'})
microsoft = df.loc[df['Ticker'] == 'MSFT', ['Date', 'Close']].rename(columns={'Close': 'MSFT'})
df_corr_1 = pd.merge(Netflix, microsoft, on='Date')

# %%
df_corr_1
# Out:
#          Date        NFLX        MSFT
# 0  2023-05-22  363.010010  321.179993
# 1  2023-05-23  355.989990  315.260010
# 2  2023-05-24  364.850006  313.850006
# 3  2023-05-25  359.000000  325.920013
# 4  2023-05-26  378.880005  332.890015
# ..        ...         ...         ...
# 58 2023-08-15  423.700012  321.859985
# 59 2023-08-16  415.450012  320.399994
# 60 2023-08-17  403.000000  316.880005
# 61 2023-08-18  404.529999  316.480011
# 62 2023-08-21  405.809998  321.609985
#
# [63 rows x 3 columns]

# %%
fig = px.scatter(df_corr_1,x = 'NFLX',y = 'MSFT',trendline='ols',title='Correlation between Microsoft and Netflix')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
